# %% [markdown]
# # 1. 確認是否使用 GPU 進行推論

# %%
! nvidia-smi
# Out:
# Wed Jun  8 09:00:48 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   53C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# # 2. 下載 Darknet 框架

# %%
! git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15420, done.
# remote: Total 15420 (delta 0), reused 0 (delta 0), pack-reused 15420
# Receiving objects: 100% (15420/15420), 14.02 MiB | 4.81 MiB/s, done.
# Resolving deltas: 100% (10362/10362), done.

# %% [markdown]
# # 3. 開始 GPU , CUDNN 功能並執行編譯

# %%
# %cd darknet
! sed -i "s/GPU=0/GPU=1/g" Makefile
! sed -i "s/CUDNN=0/CUDNN=1/g" Makefile
! sed -i "s/CUDNN_HALF=0/CUDNN_HALF=1/g" Makefile
! sed -i "s/OPENCV=0/OPENCV=1/g" Makefile
# Out:
# /content/darknet

# %%
! make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %% [markdown]
# # 4. 下載自行標註資料並訓練完成, Yolo-Fastest 模型檔案及相關設定
# 訓練過程可參考 : https://github.com/tongysmember/Yolo-fastest-and-Tiny/blob/main/ipynb/yolo-fastest-v1.1.ipynb
# 自行搜集與標註資料：https://github.com/tongysmember/Yolov4-tiny_Colab_User_Datasets

# %%
% cd ../
% cd ./content
! git clone https://github.com/tongysmember/Yolo-fastest-and-Tiny
# Out:
# /content
# [Errno 2] No such file or directory: './content'
# /content
# Cloning into 'Yolo-fastest-and-Tiny'...
# remote: Enumerating objects: 77, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 77 (delta 23), reused 40 (delta 14), pack-reused 28
# Unpacking objects: 100% (77/77), done.

# %% [markdown]
# # 5. 搬移模型及相關設定檔案

# %%
% cd Yolo-fastest-and-Tiny
# !cp ./yolo-fastest.cfg ../darknet/cfg/yolo-fastest.cfg
# !cp ./yolo-fastest_best.weights ../darknet/cfg/yolo-fastest_best.weights
# !cp ./data/my_obj.data ../darknet/data/my_obj.data
# !cp ./data/my_obj.names ../darknet/data/my_obj.names
# !cp ./data/3.png ../darknet/data/3.png
# Out:
# /content/Yolo-fastest-and-Tiny

# %%
! sed -n -e 4p -e 5p -e 6p -e 834p -e 841p -e 910p -e 917p ../darknet/cfg/yolo-fastest.cfg
# Out:
# width=320
# height=320
# channels=3
# activation=linear
# pad=1
# pad=1
# stride=1

# %% [markdown]
# # 6. 透過 Darknet 模型進行推論
# 輕量裝置上程式可透過 OpenCV 推論, 可參考 : https://github.com/tongysmember/Yolo-fastest-and-Tiny/blob/main/Yolo-Detect-CNT.py

# %%
# %cd ../darknet
# !./darknet detector test data/my_obj.data ./cfg/yolo-fastest.cfg ./cfg/yolo-fastest_best.weights  data/3.png
import cv2 # 導入OpenCV函式庫
from google.colab.patches import cv2_imshow # 導入Colab.patches函式庫

imgResult = cv2.imread('predictions.jpg') # 讀入結果影像
cv2_imshow(imgResult) # 顯示結果影像
# Out:
# /content/darknet
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv      8       3 x 3/ 2    320 x 320 x   3 ->  160 x 160 x   8 0.011 BF
#    1 conv      8       1 x 1/ 1    160 x 160 x   8 ->  160 x 160 x   8 0.003 BF
#    2 conv      8/   8  3 x 3/ 1    160 x 160 x   8 ->  160 x 160 x   8 0.004 BF
#    3 conv      4       1 x 1/ 1    160 x 160 x   8 ->  160 x 160 x   4 0.002 BF
#    4 conv      8       1 x 1/ 1    160 x 160 x   4 ->  160 x 160 x   8 0.002 BF
#    5 conv      8/   8  3 x 3/ 1    160 x 160 x   8 ->  160 x 160 x   8 0.004 BF
#    6 conv      4       1 x 1/ 1    160 x 160 x   8 ->  160 x 160 x   4 0.002 BF
# ...
